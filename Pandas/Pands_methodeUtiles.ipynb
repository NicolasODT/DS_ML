# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../_DATA/tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49  \
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
str(123456782435)[-4:] # on peut utiliser str() pour convertir un nombre en chaine de caractère
# Out:
# '2435'

# %%
def last_four(num: int):
    """
    Retourne un entier représentant les 4 derniers chiffres d'un nombre.

    Args:
        num (int): Le nombre dont on veut récupérer les 4 derniers chiffres.

    Returns:
        int: Un entier représentant les 4 derniers chiffres du nombre.
    """
    return int(str(num)[-4:])

# %%
last_four(1234567890)
# Out:
# 7890

# %%
df['last_four'] = df['CC Number'].apply(last_four) # on applique la fonction sur la colonne CC Number
#apply() permet d'appliquer une fonction sur une colonne

df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49  \
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  last_four
# 0  Christy Cunningham  3560325168603410    Sun2959       3410
# 1      Douglas Tucker  4478071379779230    Sun4608       9230
# 2      Travis Walters  6011812112971322    Sun4458       1322
# 3    Nathaniel Harris  4676137647685994    Sun5260       5994
# 4        Tonya Carter  4832732618637221    Sun2251       7221

# %%
df['total_bill'].mean() # moyenne de la colonne total_bill
# Out:
# 19.78594262295082

# %%
def yelp(price: float) -> str:
    """
    Retourne une chaîne de caractères représentant le niveau de prix d'un restaurant en fonction du prix total de la facture.

    Args:
        price (float): Le prix total de la facture.

    Returns:
        str: Une chaîne de caractères représentant le niveau de prix du restaurant.
            - "$" si le prix total de la facture est inférieur à 10.
            - "$$" si le prix total de la facture est compris entre 10 et 30.
            - "$$$" si le prix total de la facture est supérieur ou égal à 30.
    """
    if price < 10:
        return '$'
    elif price >= 10 and price < 30:
        return '$$'
    else:
        return '$$$'

# %%
df['yelp'] = df['total_bill'].apply(yelp) # on applique la fonction sur la colonne total_bill
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49  \
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  last_four yelp
# 0  Christy Cunningham  3560325168603410    Sun2959       3410   $$
# 1      Douglas Tucker  4478071379779230    Sun4608       9230   $$
# 2      Travis Walters  6011812112971322    Sun4458       1322   $$
# 3    Nathaniel Harris  4676137647685994    Sun5260       5994   $$
# 4        Tonya Carter  4832732618637221    Sun2251       7221   $$

# %%
lambda num: num*2 # lambda est une fonction anonyme
# Out:
# <function __main__.<lambda>(num)>

# %%
df['total_bill'].apply(lambda num: num*2) # on applique la fonction lambda sur la colonne total_bill
# Out:
# 0      33.98
# 1      20.68
# 2      42.02
# 3      47.36
# 4      49.18
#        ...
# 239    58.06
# 240    54.36
# 241    45.34
# 242    35.64
# 243    37.56
# Name: total_bill, Length: 244, dtype: float64

# %%
def quality(total_bill: float, tip: float) -> str:
    """
    Retourne une chaîne de caractères représentant la qualité du pourboire en fonction du pourcentage de pourboire par rapport au total de la facture.

    Si le pourboire représente plus de 20% du total de la facture, la fonction retourne "Generous". Sinon, elle retourne "Other".

    Args:
        total_bill (float): Le montant total de la facture.
        tip (float): Le montant du pourboire.

    Returns:
        str: Une chaîne de caractères représentant la qualité du pourboire.
            - "Generous" si le pourboire représente plus de 20% du total de la facture.
            - "Other" sinon.
    """
    if tip / total_bill > 0.20:
        return "Generous"
    else:
        return "Other"

# %%
quality(15.55, 5.01)
# Out:
# 'Generous'

# %%
df['Quality'] = df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'], df['tip']), axis=1) # on applique la fonction lambda sur les colonnes total_bill et tip

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49  \
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  last_four yelp Quality
# 0  Christy Cunningham  3560325168603410    Sun2959       3410   $$   Other
# 1      Douglas Tucker  4478071379779230    Sun4608       9230   $$   Other
# 2      Travis Walters  6011812112971322    Sun4458       1322   $$   Other
# 3    Nathaniel Harris  4676137647685994    Sun5260       5994   $$   Other
# 4        Tonya Carter  4832732618637221    Sun2251       7221   $$   Other

# %%
df['Quality'] = np.vectorize(quality)(df['total_bill'], df['tip']) # meilleure façon de faire 
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49  \
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  last_four yelp Quality
# 0  Christy Cunningham  3560325168603410    Sun2959       3410   $$   Other
# 1      Douglas Tucker  4478071379779230    Sun4608       9230   $$   Other
# 2      Travis Walters  6011812112971322    Sun4458       1322   $$   Other
# 3    Nathaniel Harris  4676137647685994    Sun5260       5994   $$   Other
# 4        Tonya Carter  4832732618637221    Sun2251       7221   $$   Other

# %%
import timeit # permet de mesurer le temps d'exécution d'une fonction

# %%
setup = '''
import numpy as np
import pandas as pd
df = pd.read_csv('../_DATA/tips.csv')
def quality(total_bill, tip):
    if tip/total_bill > 0.20:
        return "Generous"
    else:
        return "Other"
'''

# %%
stmt_one = '''
df['Tip Quality'] = df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'], df['tip']), axis=1)
'''

stmt_two = '''
df['Tip Quality'] = np.vectorize(quality)(df['total_bill'], df['tip'])
'''

# %%
timeit.timeit(setup=setup, stmt=stmt_one, number=1000)
# Out:
# 1.2323786000051768

# %%
timeit.timeit(setup=setup, stmt=stmt_two, number=1000)
# Out:
# 0.1373252999910619

# %%
df = pd.read_csv('../_DATA/tips.csv') # reset du dataframe

# %%
df.describe() # statistiques descriptives
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.sort_values(['tip','size'],ascending=False) # trier les données par tip et size
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94  \
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df['total_bill'].max() # valeur max de la colonne total_bill
# Out:
# 50.81

# %%
df['total_bill'].idxmax() # index de la valeur max de la colonne total_bill
# Out:
# 170

# %%
df.iloc[170] # afficher la ligne de l'index 170
# Out:
# total_bill                     50.81
# tip                             10.0
# sex                             Male
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               3
# price_per_person               16.94
# Payer Name             Gregory Clark
# CC Number           5473850968388236
# Payment ID                   Sat1954
# Name: 170, dtype: object

# %%
df.loc[df['total_bill'].idxmax()] # on a utilisé la fonction idxmax() pour afficher la ligne de l'index de la valeur max de la colonne total_bill
# Out:
# total_bill                     50.81
# tip                             10.0
# sex                             Male
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               3
# price_per_person               16.94
# Payer Name             Gregory Clark
# CC Number           5473850968388236
# Payment ID                   Sat1954
# Name: 170, dtype: object

# %%
df.select_dtypes(['int', 'float']).corr() # calculer la corrélation entre les colonnes numériques
# Out:
#                   total_bill       tip      size  price_per_person  CC Number
# total_bill          1.000000  0.675734  0.598315          0.647554   0.104576
# tip                 0.675734  1.000000  0.489299          0.347405   0.110857
# size                0.598315  0.489299  1.000000         -0.175359  -0.030239
# price_per_person    0.647554  0.347405 -0.175359          1.000000   0.135240
# CC Number           0.104576  0.110857 -0.030239          0.135240   1.000000

# %%
df['sex'].value_counts() # compter le nombre de valeurs par catégorie
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df['day'].unique() # afficher les valeurs uniques de la colonne day
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df['day'].nunique() # afficher le nombre de valeurs uniques de la colonne day
# Out:
# 4

# %%
len(df['day'].unique()) # afficher le nombre de valeurs uniques de la colonne day
# Out:
# 4

# %%
df['day'].value_counts() # compter le nombre de valeurs par catégorie
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49  \
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df['sex'].replace(['Female', 'Male'], ['F','M']) # On remplace Female et Male par F et M
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %%
my_map = {'Female':'F','Male':'M'} # on crée un dictionnaire

# %%
df['sex'].map(my_map)
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %%
df.duplicated() # afficher les lignes dupliquées
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Length: 244, dtype: bool

# %%
simple_df = pd.DataFrame([1,2,2,2], index=['a','b','c','d'])
simple_df.duplicated() # afficher les lignes dupliquées
# Out:
# a    False
# b    False
# c     True
# d     True
# dtype: bool

# %%
simple_df.drop_duplicates() # supprimer les lignes dupliquées
# Out:
#    0
# a  1
# b  2

# %%
df[df['total_bill'].between(19,20)] # afficher les valeurs comprises entre 19 et 20
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person
# 24        19.82  3.18    Male     No   Sat  Dinner     2              9.91  \
# 29        19.65  3.00  Female     No   Sat  Dinner     2              9.82
# 55        19.49  3.51    Male     No   Sun  Dinner     2              9.74
# 80        19.44  3.00    Male    Yes  Thur   Lunch     2              9.72
# 130       19.08  1.50    Male     No  Thur   Lunch     2              9.54
# 154       19.77  2.00    Male     No   Sun  Dinner     4              4.94
# 191       19.81  4.19  Female    Yes  Thur   Lunch     2              9.90
#
#            Payer Name         CC Number Payment ID
# 24   Christopher Ross    36739148167928    Sat6236
# 29     Melinda Murphy  5489272944576051    Sat2467
# 55   Michael Hamilton  6502227786581768    Sun1118
# 80       Louis Torres    38848369968464   Thur6453
# 130       Seth Sexton   213113680829581   Thur1446
# 154       James Smith   213169731428229    Sun5814
# ...

# %%
df.nlargest(5, 'tip') # afficher les 5 plus grandes valeurs de la colonne tip
# Out:
#      total_bill    tip   sex smoker   day    time  size  price_per_person
# 170       50.81  10.00  Male    Yes   Sat  Dinner     3             16.94  \
# 212       48.33   9.00  Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58  Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73  Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70  Male     No  Thur   Lunch     6              5.72
#
#           Payer Name         CC Number Payment ID
# 170    Gregory Clark  5473850968388236    Sat1954
# 212  Alex Williamson      676218815212    Sat4590
# 23    Lance Peterson  3542584061609808     Sat239
# 59       Brian Ortiz  6596453823950595    Sat8139
# 141   Steven Carlson  3526515703718508   Thur1025

# %%
df.sort_values('tip', ascending=False).iloc[:5] # mauvaise façon de faire
# Out:
#      total_bill    tip   sex smoker   day    time  size  price_per_person
# 170       50.81  10.00  Male    Yes   Sat  Dinner     3             16.94  \
# 212       48.33   9.00  Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58  Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73  Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70  Male     No  Thur   Lunch     6              5.72
#
#           Payer Name         CC Number Payment ID
# 170    Gregory Clark  5473850968388236    Sat1954
# 212  Alex Williamson      676218815212    Sat4590
# 23    Lance Peterson  3542584061609808     Sat239
# 59       Brian Ortiz  6596453823950595    Sat8139
# 141   Steven Carlson  3526515703718508   Thur1025

# %%
df.nsmallest(5, 'tip') # afficher les 5 plus petites valeurs de la colonne tip
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1              3.07  \
# 92         5.75  1.00  Female    Yes  Fri  Dinner     2              2.88
# 111        7.25  1.00  Female     No  Sat  Dinner     1              7.25
# 236       12.60  1.00    Male    Yes  Sat  Dinner     2              6.30
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49
#
#              Payer Name         CC Number Payment ID
# 67        Tiffany Brock  4359488526995267    Sat3455
# 92         Leah Ramirez  3508911676966392    Fri3780
# 111         Terri Jones  3559221007826887    Sat4801
# 236       Matthew Myers  3543676378973965    Sat5032
# 0    Christy Cunningham  3560325168603410    Sun2959

# %%
df.sort_values('tip', ascending=True).iloc[:5] # mauvaise façon de faire
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1              3.07  \
# 236       12.60  1.00    Male    Yes  Sat  Dinner     2              6.30
# 92         5.75  1.00  Female    Yes  Fri  Dinner     2              2.88
# 111        7.25  1.00  Female     No  Sat  Dinner     1              7.25
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49
#
#              Payer Name         CC Number Payment ID
# 67        Tiffany Brock  4359488526995267    Sat3455
# 236       Matthew Myers  3543676378973965    Sat5032
# 92         Leah Ramirez  3508911676966392    Fri3780
# 111         Terri Jones  3559221007826887    Sat4801
# 0    Christy Cunningham  3560325168603410    Sun2959

# %%
df.sample(frac=0.05) # afficher 5% des données aléatoirement
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person
# 116       29.93  5.07    Male     No   Sun  Dinner     4              7.48  \
# 107       25.21  4.29    Male    Yes   Sat  Dinner     2             12.60
# 35        24.06  3.60    Male     No   Sat  Dinner     3              8.02
# 200       18.71  4.00    Male    Yes  Thur   Lunch     3              6.24
# 97        12.03  1.50    Male    Yes   Fri  Dinner     2              6.02
# 189       23.10  4.00    Male    Yes   Sun  Dinner     3              7.70
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2              6.71
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2              6.45
# 43         9.68  1.32    Male     No   Sun  Dinner     2              4.84
# 209       12.76  2.23  Female    Yes   Sat  Dinner     2              6.38
# 66        16.45  2.47  Female     No   Sat  Dinner     2              8.22
# ...
